# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("globalterrorismdb_0718dist.csv", encoding='latin1')
# Out:
# C:\Users\ranja\AppData\Local\Temp\ipykernel_5552\3039072619.py:1: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("globalterrorismdb_0718dist.csv", encoding='latin1')

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
# here we are intrested in some major columns so we selected that ones
df1=df[['eventid', 'iyear', 'imonth', 'iday', 'extended',
       'resolution', 'country', 'country_txt', 'region', 'region_txt',
       'provstate', 'city', 'latitude', 'longitude','attacktype1_txt','weaptype1_txt','nkill','gname']]

# %%
df1.head()
# Out:
#         eventid  iyear  imonth  iday  extended resolution  country  \
# 0  197000000001   1970       7     2         0        NaN       58
# 1  197000000002   1970       0     0         0        NaN      130
# 2  197001000001   1970       1     0         0        NaN      160
# 3  197001000002   1970       1     0         0        NaN       78
# 4  197001000003   1970       1     0         0        NaN      101
#
#           country_txt  region                   region_txt provstate  \
# 0  Dominican Republic       2  Central America & Caribbean       NaN
# 1              Mexico       1                North America   Federal
# 2         Philippines       5               Southeast Asia    Tarlac
# 3              Greece       8               Western Europe    Attica
# 4               Japan       4                    East Asia   Fukouka
#
#             city   latitude   longitude                 attacktype1_txt  \
# ...

# %%
df1.hist(figsize=(20,30))
# Out:
# array([[<AxesSubplot: title={'center': 'eventid'}>,
#         <AxesSubplot: title={'center': 'iyear'}>,
#         <AxesSubplot: title={'center': 'imonth'}>],
#        [<AxesSubplot: title={'center': 'iday'}>,
#         <AxesSubplot: title={'center': 'extended'}>,
#         <AxesSubplot: title={'center': 'country'}>],
#        [<AxesSubplot: title={'center': 'region'}>,
#         <AxesSubplot: title={'center': 'latitude'}>,
#         <AxesSubplot: title={'center': 'longitude'}>],
#        [<AxesSubplot: title={'center': 'nkill'}>, <AxesSubplot: >,
#         <AxesSubplot: >]], dtype=object)

# %%
sns.heatmap(np.round(df1.corr(),2),annot=True, cmap='BuPu')
# Out:
# C:\Users\ranja\AppData\Local\Temp\ipykernel_5552\962250406.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(np.round(df1.corr(),2),annot=True, cmap='BuPu')
# <AxesSubplot: >

# %%
pd.crosstab(df1.iyear,df1.region_txt).plot(kind='area', figsize=(10,6))
plt.title('Activites by terrorists in region vs year')
plt.ylabel('no of attacks')
plt.show()

# %% [markdown]
# # No of Attacks per year

# %%
plt.subplots(figsize=(10, 6))
sns.countplot(data=df1, x='iyear', palette='RdYlGn_r', edgecolor=sns.color_palette("YlOrBr", 10))
plt.xticks(rotation=90)
plt.title('Number Of Terrorist Activities Each Year')
# Out:
# Text(0.5, 1.0, 'Number Of Terrorist Activities Each Year')

# %% [markdown]
# # Methods of Attacks

# %%
plt.subplots(figsize=(10, 6))
sns.countplot(data=df1, x='attacktype1_txt', palette='RdYlGn_r', edgecolor=sns.color_palette("YlOrBr", 10))
plt.xticks(rotation=90)
plt.title('Methods Of Terrorist Attacks')
# Out:
# Text(0.5, 1.0, 'Methods Of Terrorist Attacks')

# %%
plt.subplots(figsize=(10, 6))
sns.countplot(data=df1, x='weaptype1_txt', palette='RdYlGn_r', edgecolor=sns.color_palette("YlOrBr", 10))
plt.xticks(rotation=90)
plt.title('weapons Of Terrorist Attacks')
# Out:
# Text(0.5, 1.0, 'weapons Of Terrorist Attacks')

# %%
df.columns[50:100]
# Out:
# Index(['targtype3', 'targtype3_txt', 'targsubtype3', 'targsubtype3_txt',
#        'corp3', 'target3', 'natlty3', 'natlty3_txt', 'gname', 'gsubname',
#        'gname2', 'gsubname2', 'gname3', 'gsubname3', 'motive', 'guncertain1',
#        'guncertain2', 'guncertain3', 'individual', 'nperps', 'nperpcap',
#        'claimed', 'claimmode', 'claimmode_txt', 'claim2', 'claimmode2',
#        'claimmode2_txt', 'claim3', 'claimmode3', 'claimmode3_txt', 'compclaim',
#        'weaptype1', 'weaptype1_txt', 'weapsubtype1', 'weapsubtype1_txt',
#        'weaptype2', 'weaptype2_txt', 'weapsubtype2', 'weapsubtype2_txt',
#        'weaptype3', 'weaptype3_txt', 'weapsubtype3', 'weapsubtype3_txt',
#        'weaptype4', 'weaptype4_txt', 'weapsubtype4', 'weapsubtype4_txt',
#        'weapdetail', 'nkill', 'nkillus'],
#       dtype='object')

# %%
plt.subplots(figsize=(10, 6))
sns.barplot(y=df1['gname'].value_counts()[1:12].index,x=df1['gname'].value_counts()[1:12].values,
           palette='copper')
plt.xticks(rotation=90)
plt.title('weapons Of Terrorist Attacks')
# Out:
# Text(0.5, 1.0, 'weapons Of Terrorist Attacks')

# %%
fig,axes = plt.subplots(figsize=(16,11),nrows=1,ncols=2)
sns.barplot(x = df1['country'].value_counts()[:20].values, y = df1['country'].value_counts()[:20].index, 
            ax=axes[0],palette = 'magma');
axes[0].set_title('Terrorist Attacks per Country')
sns.barplot(x=df1['region_txt'].value_counts().values,y=df1['region_txt'].value_counts().index,
            ax=axes[1])
axes[1].set_title('Terrorist Attacks per Region')
fig.tight_layout()
plt.show()
# Out:
# C:\Users\ranja\AppData\Local\Temp\ipykernel_5552\3710123940.py:2: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   sns.barplot(x = df1['country'].value_counts()[:20].values, y = df1['country'].value_counts()[:20].index,
# C:\Users\ranja\AppData\Local\Temp\ipykernel_5552\3710123940.py:2: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   sns.barplot(x = df1['country'].value_counts()[:20].values, y = df1['country'].value_counts()[:20].index,

# %%
sns.catplot(x='iyear',y='nkill',data=df1)

# %%
x = df1['nkill'][0:200].value_counts()
plt.pie(x.values,labels=x.index)
plt.figsize=(100,100)
plt.show()

# %%
# showing the co-relations.
df1.corr()
# Out:
# C:\Users\ranja\AppData\Local\Temp\ipykernel_5552\4152625287.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df1.corr()
#             eventid     iyear    imonth      iday  extended   country  \
# eventid    1.000000  0.999996  0.002706  0.018336  0.091761 -0.135039
# iyear      0.999996  1.000000  0.000139  0.018254  0.091754 -0.135023
# imonth     0.002706  0.000139  1.000000  0.005497 -0.000468 -0.006305
# iday       0.018336  0.018254  0.005497  1.000000 -0.004700  0.003468
# extended   0.091761  0.091754 -0.000468 -0.004700  1.000000 -0.020466
# country   -0.135039 -0.135023 -0.006305  0.003468 -0.020466  1.000000
# region     0.401371  0.401384 -0.002999  0.009710  0.038389  0.148597
# latitude   0.166886  0.166933 -0.015978  0.003423 -0.024749  0.178567
# ...

# %% [markdown]
# # Results from this EDA:

# %% [markdown]
# 1. In many cases the most people killed is 0
# 2. Most active group is Taliban with highest no of wepons.
# 3. As we can see  year by year terrorism is growing till 2014 then it starts decreasing
# 4. mostly the bombing method is used by the terrorists;
# 5. western europe has the most attacks.
# 6. The Middle East and North Africa Regions has most taregeted.
